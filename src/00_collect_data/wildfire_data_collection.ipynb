# %% [markdown]
# # Wildfire Incident Data Collection
# For wildfire incidence data collection we used [National Interagency Fire Center - WFIGS (Wildland Fire Interagency Geospacial Services Database)](https://data-nifc.opendata.arcgis.com/datasets/nifc::wfigs-wildland-fire-locations-full-history/explore?filters=eyJDb250cm9sRGF0ZVRpbWUiOls5OTg5MDM4NTU2ODcuNjEsMTY3MzA0NDMyMDAwMF19&location=37.093867%2C-117.175606%2C7.00&showTable=true).
# The data collected from WFIGS includes the point locations for all reported wildland fires in the United States. However, the dataset we got focuses on South-Western portion of the US.
#
# From their website:
# > The Wildland Fire Interagency Geospatial Services (WFIGS) Group provides authoritative geospatial data products under the interagency Wildland Fire Data Program. Hosted in the National Interagency Fire Center ArcGIS Online Organization (The NIFC Org), WFIGS provides both internal and public facing data, accessible in a variety of formats.
# > This service contains all wildland fire incidents from the IRWIN (Integrated Reporting of Wildland Fire Information) integration service and historical data converted to the IRWIN schema.

# %%
# Library imports
import pandas as pd

# %%
# Import of the source data
df = pd.read_csv('../../data/raw/WFIGS_-_Wildland_Fire_Locations_Full_History (3).csv', low_memory = False)
df.head()
# Out:
#             X          Y  OBJECTID ABCDMisc ADSPermissionState  \
# 0 -111.414812  40.072836         7      NaN            DEFAULT
# 1 -112.439311  34.403275        13      NaN            DEFAULT
# 2 -108.895411  40.239896        31      NaN            DEFAULT
# 3 -108.552111  38.145376        35      NaN            DEFAULT
# 4 -111.348611  33.195755        51      NaN            DEFAULT
#
#    CalculatedAcres     ContainmentDateTime         ControlDateTime  \
# 0              NaN  2019/10/31 16:30:00+00  2019/11/05 18:30:00+00
# 1              NaN  2019/09/09 17:00:00+00  2019/09/09 17:00:00+00
# 2              NaN  2019/07/30 18:00:00+00  2019/08/03 14:00:00+00
# 3              NaN  2018/07/28 03:14:59+00  2018/07/28 14:39:59+00
# 4              NaN  2020/07/23 05:29:59+00  2020/07/23 05:29:59+00
#
#    DailyAcres  DiscoveryAcres  ... IsDispatchComplete  \
# 0       170.0             0.1  ...                  0
# 1         0.1             0.5  ...                  0
# 2        90.0             1.0  ...                  0
# 3         0.1             0.1  ...                  0
# 4         8.0             2.5  ...                  0
#
#    OrganizationalAssessment  StrategicDecisionPublishDate  \
# 0           Type 4 Incident                           NaN
# 1                       NaN                           NaN
# 2                       NaN                           NaN
# 3                       NaN                           NaN
# 4                       NaN                           NaN
#
#      CreatedOnDateTime_dt   ModifiedOnDateTime_dt Source  \
# 0  2019/10/27 00:14:29+00  2019/11/13 00:15:39+00  IRWIN
# 1  2019/09/05 20:14:11+00  2019/09/14 19:28:38+00  IRWIN
# 2  2019/07/28 22:52:13+00  2019/08/10 18:31:55+00  IRWIN
# 3  2018/07/28 17:50:47+00  2018/07/29 21:56:13+00  IRWIN
# 4  2020/07/22 22:56:30+00  2020/08/09 00:10:34+00  IRWIN
#
#                                  GlobalID IsCpxChild CpxName CpxID
# 0  {BFD53772-94E7-43F0-9D2C-62444A07CA68}        NaN     NaN   NaN
# 1  {E656CA4D-EECE-4746-AEE3-4D645C4F1F13}        NaN     NaN   NaN
# 2  {50C0D06E-E3DC-4094-BF22-B9D4B7BA68B1}        NaN     NaN   NaN
# 3  {496DBF20-6556-490D-8B22-1E79AEEE74C7}        NaN     NaN   NaN
# 4  {9E1157E6-8784-42A5-9F43-D740C4ED357F}        NaN     NaN   NaN
#
# [5 rows x 96 columns]

# %%
# Checking dimensions
df.shape
# Out:
# (33564, 96)

# %%
# Checking data types, and missing values
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33564 entries, 0 to 33563
# Data columns (total 96 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   X                                33564 non-null  float64
#  1   Y                                33564 non-null  float64
#  2   OBJECTID                         33564 non-null  int64
#  3   ABCDMisc                         4181 non-null   object
#  4   ADSPermissionState               33564 non-null  object
#  5   CalculatedAcres                  967 non-null    float64
#  6   ContainmentDateTime              33113 non-null  object
#  7   ControlDateTime                  33564 non-null  object
#  8   DailyAcres                       33139 non-null  float64
#  9   DiscoveryAcres                   32900 non-null  float64
#  10  DispatchCenterID                 33380 non-null  object
#  11  EstimatedCostToDate              1167 non-null   float64
#  12  FinalFireReportApprovedByTitle   0 non-null      float64
#  13  FinalFireReportApprovedByUnit    0 non-null      float64
#  14  FinalFireReportApprovedDate      10925 non-null  object
#  15  FireBehaviorGeneral              1163 non-null   object
#  16  FireBehaviorGeneral1             1045 non-null   object
#  17  FireBehaviorGeneral2             1003 non-null   object
#  18  FireBehaviorGeneral3             781 non-null    object
#  19  FireCause                        33515 non-null  object
#  20  FireCauseGeneral                 12635 non-null  object
#  21  FireCauseSpecific                2600 non-null   object
#  22  FireCode                         23976 non-null  object
#  23  FireDepartmentID                 75 non-null     object
#  24  FireDiscoveryDateTime            33564 non-null  object
#  25  FireMgmtComplexity               1235 non-null   object
#  26  FireOutDateTime                  29335 non-null  object
#  27  FireStrategyConfinePercent       1163 non-null   float64
#  28  FireStrategyFullSuppPercent      1163 non-null   float64
#  29  FireStrategyMonitorPercent       1163 non-null   float64
#  30  FireStrategyPointZonePercent     1163 non-null   float64
#  31  FSJobCode                        19375 non-null  object
#  32  FSOverrideCode                   18786 non-null  object
#  33  GACC                             33562 non-null  object
#  34  ICS209ReportDateTime             1153 non-null   object
#  35  ICS209ReportForTimePeriodFrom    1163 non-null   object
#  36  ICS209ReportForTimePeriodTo      1163 non-null   object
#  37  ICS209ReportStatus               1163 non-null   object
#  38  IncidentManagementOrganization   1163 non-null   object
#  39  IncidentName                     33564 non-null  object
#  40  IncidentShortDescription         1163 non-null   object
#  41  IncidentTypeCategory             33564 non-null  object
#  42  IncidentTypeKind                 33564 non-null  object
#  43  InitialLatitude                  32396 non-null  float64
#  44  InitialLongitude                 32396 non-null  float64
#  45  InitialResponseAcres             20630 non-null  float64
#  46  InitialResponseDateTime          10648 non-null  object
#  47  IrwinID                          33564 non-null  object
#  48  IsFireCauseInvestigated          2217 non-null   float64
#  49  IsFireCodeRequested              33564 non-null  int64
#  50  IsFSAssisted                     32090 non-null  float64
#  51  IsMultiJurisdictional            31582 non-null  float64
#  52  IsReimbursable                   31582 non-null  float64
#  53  IsTrespass                       31602 non-null  float64
#  54  IsUnifiedCommand                 653 non-null    float64
#  55  LocalIncidentIdentifier          33564 non-null  object
#  56  PercentContained                 1178 non-null   float64
#  57  PercentPerimeterToBeContained    1179 non-null   float64
#  58  POOCity                          599 non-null    object
#  59  POOCounty                        33564 non-null  object
#  60  POODispatchCenterID              33561 non-null  object
#  61  POOFips                          33564 non-null  object
#  62  POOJurisdictionalAgency          25543 non-null  object
#  63  POOJurisdictionalUnit            26008 non-null  object
#  64  POOJurisdictionalUnitParentUnit  0 non-null      float64
#  65  POOLandownerCategory             29936 non-null  object
#  66  POOLandownerKind                 29909 non-null  object
#  67  POOLegalDescPrincipalMeridian    180 non-null    object
#  68  POOLegalDescQtr                  63 non-null     object
#  69  POOLegalDescQtrQtr               56 non-null     object
#  70  POOLegalDescRange                169 non-null    object
#  71  POOLegalDescSection              169 non-null    float64
#  72  POOLegalDescTownship             169 non-null    object
#  73  POOPredictiveServiceAreaID       33559 non-null  object
#  74  POOProtectingAgency              32959 non-null  object
#  75  POOProtectingUnit                33564 non-null  object
#  76  POOState                         33564 non-null  object
#  77  PredominantFuelGroup             11291 non-null  object
#  78  PredominantFuelModel             11258 non-null  object
#  79  PrimaryFuelModel                 1163 non-null   object
#  80  SecondaryFuelModel               1001 non-null   object
#  81  TotalIncidentPersonnel           1124 non-null   float64
#  82  UniqueFireIdentifier             33564 non-null  object
#  83  WFDSSDecisionStatus              33563 non-null  object
#  84  CreatedBySystem                  33564 non-null  object
#  85  ModifiedBySystem                 33564 non-null  object
#  86  IsDispatchComplete               33564 non-null  int64
#  87  OrganizationalAssessment         711 non-null    object
#  88  StrategicDecisionPublishDate     667 non-null    object
#  89  CreatedOnDateTime_dt             33564 non-null  object
#  90  ModifiedOnDateTime_dt            33564 non-null  object
#  91  Source                           33564 non-null  object
#  92  GlobalID                         33564 non-null  object
#  93  IsCpxChild                       10180 non-null  float64
#  94  CpxName                          56 non-null     object
#  95  CpxID                            56 non-null     object
# dtypes: float64(27), int64(3), object(66)
# memory usage: 24.6+ MB

# %%
# Removing some columns that we do not need and ones that have mostly missing values
cols = ['FireBehaviorGeneral', 'FireBehaviorGeneral1', 'FireBehaviorGeneral2', 'FireBehaviorGeneral3', 'FireDepartmentID', 'FireStrategyConfinePercent', 'FireStrategyFullSuppPercent', 
        'FireStrategyMonitorPercent', 'FireStrategyPointZonePercent', 'FSJobCode', 'FSOverrideCode', 'GACC', 'ICS209ReportDateTime', 'ICS209ReportForTimePeriodFrom', 
        'ICS209ReportForTimePeriodTo', 'ICS209ReportStatus', 'IncidentManagementOrganization', 'WFDSSDecisionStatus', 'CreatedBySystem', 'ModifiedBySystem', 'IsDispatchComplete', 
        'OrganizationalAssessment', 'StrategicDecisionPublishDate', 'CreatedOnDateTime_dt', 'ModifiedOnDateTime_dt', 'Source', 'GlobalID', 'IsCpxChild', 'CpxName', 'CpxID', 
        'POOFips', 'POOJurisdictionalAgency', 'POOJurisdictionalUnit', 'POOJurisdictionalUnitParentUnit', 'POOLandownerCategory', 'POOLandownerKind', 'POOLegalDescPrincipalMeridian', 
        'POOLegalDescQtr', 'POOLegalDescQtrQtr', 'POOLegalDescRange', 'POOLegalDescSection', 'POOLegalDescTownship', 'POOPredictiveServiceAreaID', 'POOProtectingAgency', 'POOProtectingUnit']

df = df.drop(columns = cols)

# %%
# Adding id column to sync it with API results:
df['id'] = df.index

# %%
# Export of the collected dataset
df.to_csv('../../data/raw/wildfire_all.csv', index=False)
